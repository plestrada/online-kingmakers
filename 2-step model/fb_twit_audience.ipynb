# %% [markdown]
# ## Profiling mentions of and comments about candidates

# %%
import pandas as pd
import numpy as np
import glob
import re

import emoji
import googletrans
from googletrans import Translator
from watson_developer_cloud import PersonalityInsightsV3 as PersonalityInsights
import json
import nltk
import string
from nltk.stem.wordnet import WordNetLemmatizer

# %% [markdown]
# ## Profiling Facebook comments

# %%
fb_df = pd.read_csv('fb_cleaned_070120.csv')

# %%
fb_df.columns
# Out:
# Index(['Unnamed: 0', 'Post_url', 'Post_text', 'Date', 'Shares', 'Reactions',
#        'User', 'Comment', 'ID', 'Candidate', 'Shares_Count', 'Reactions_Count',
#        'Reaction1', 'Reaction2', 'Reaction3'],
#       dtype='object')

# %%
fb_df = fb_df[['Candidate', 'Comment']]

# %%
fb_df.head()
# Out:
#   Candidate                                            Comment  Platform
# 0   Bong Go  Salamat Mr. President you are the best and APO...  Facebook
# 1   Bong Go                 Thank you Tatay Digong Love you ♥️  Facebook
# 2   Bong Go  Salamat tatay digong!You are the best ...god b...  Facebook
# 3   Bong Go                Thank you tatay digong sa greetings  Facebook
# 4   Bong Go  Thank you po tatay Digong! 😍 God bless you alw...  Facebook

# %%
fb_df.shape
# Out:
# (113621, 3)

# %%
fb_df.isnull().sum()
# Out:
# Candidate    0
# Comment      0
# Platform     0
# dtype: int64

# %%
fb_df=fb_df[(fb_df['Comment']!='None') & (fb_df['Comment']!='[]')]

# %%
fb_df.shape
# Out:
# (107806, 3)

# %%
fb_df['Comment'] = fb_df['Comment'].apply(emoji.demojize)

# %%
fb_df.head()
# Out:
#   Candidate                                            Comment  Platform
# 0   Bong Go  Salamat Mr. President you are the best and APO...  Facebook
# 1   Bong Go       Thank you Tatay Digong Love you :heart_suit:  Facebook
# 2   Bong Go  Salamat tatay digong!You are the best ...god b...  Facebook
# 3   Bong Go                Thank you tatay digong sa greetings  Facebook
# 4   Bong Go  Thank you po tatay Digong! :smiling_face_with_...  Facebook

# %%
cndlist=[]
cmtlist=[]
cmtcount=[]

for i in fb_df['Candidate'].unique():
    cndlist.append(i)
    cmtlist.append(' '.join((fb_df[fb_df['Candidate']==i]['Comment']).to_list()))
    cmtcount.append(len(fb_df[fb_df['Candidate']==i]))

fb_df_summary=pd.DataFrame({'Candidate': cndlist, 'Comment': cmtlist, 'Comment Count': cmtcount})

# %%
fb_df_summary['Platform']='Facebook'

# %%
fb_df_summary.shape
# Out:
# (52, 4)

# %%
fb_df_summary['Comment'] = fb_df_summary['Comment'].apply(str).apply(lambda x: x.replace('[','').replace(']','').strip())

# %%
translator = Translator()
# fb_df_summary['Translated_text'] = fb_df_summary['Comment'].apply(str).apply(translator.translate).apply(lambda x: x.text)

# %%
trans=[]

for i in range(len(fb_df_summary)):
    try:
        trans.append(translator.translate(fb_df_summary['Comment'][i]).text)
        print(str(i) + " ok")
    except:
        trans.append(fb_df_summary['Comment'][i])
        print(str(i) + " can't translate")
# Out:
# 0 ok
# 1 ok
# 2 ok
# 3 ok
# 4 ok
# 5 ok
# 6 can't translate
# 7 ok
# 8 ok
# 9 ok
# 10 ok
# 11 ok
# 12 ok
# 13 can't translate
# 14 ok
# 15 can't translate
# 16 ok
# 17 ok
# 18 ok
# 19 ok
# 20 can't translate
# 21 ok
# 22 can't translate
# 23 ok
# 24 ok
# 25 ok
# 26 ok
# 27 ok
# 28 ok
# 29 ok
# 30 ok
# 31 ok
# 32 ok
# 33 ok
# 34 ok
# 35 ok
# 36 ok
# 37 ok
# 38 ok
# 39 can't translate
# 40 ok
# 41 ok
# 42 ok
# 43 ok
# 44 ok
# 45 ok
# 46 ok
# 47 ok
# 48 ok
# 49 ok
# 50 ok
# 51 ok

# %%
fb_df_summary['Translated_text'] = trans

# %%
fb_df_summary.head()
# Out:
#          Candidate                                            Comment  \
# 0          Bong Go  Salamat Mr. President you are the best and APO...
# 1    Charlie Gaddi  'Pagpapalain nawA po kayo!...' tanong ko lang ...
# 2  Bernard Austria  Good luck Kuya Berns... :smiling_face: Godbles...
# 3     Abner Afuang  I vote for you po True :thumbs_up::thumbs_up::...
# 4     Raffy Alunan  Vote ko PO kau Vote alunan I voted for you mr ...
#
#    Comment Count  Platform                                    Translated_text
# 0           1929  Facebook  Salamat Mr. President you are the best and APO...
# 1              3  Facebook  'Blessed be you! ...' I only asked if you were...
# 2              8  Facebook  Good luck Kuya Berns ...: smiling_face: Godble...
# 3            404  Facebook  I vote for you po True :thumbs_up::thumbs_up::...
# 4           4607  Facebook  Vote ko PO kau Vote alunan I voted for you mr ...

# %%
stopwords = set(nltk.corpus.stopwords.words('english'))
punctuation = string.punctuation
lemmatizer = WordNetLemmatizer()


def text_cleaner(row):
    words=[]
    for sent in nltk.sent_tokenize(row):
        for word in nltk.wordpunct_tokenize(sent):
            word = word.lower()
            word = lemmatizer.lemmatize(word)
            if word not in stopwords and word not in punctuation:
                words.append(word)
    word_count=len(words)
    clean_text=' '.join(words)
    return word_count, clean_text

# %%
fb_df_summary['word_count'] = fb_df_summary['Translated_text'].apply(text_cleaner).apply(lambda x: x[0])
fb_df_summary['clean_text'] = fb_df_summary['Translated_text'].apply(text_cleaner).apply(lambda x: x[1])

# %%
fb_df_summary.head()
# Out:
#          Candidate                                            Comment  \
# 0          Bong Go  Salamat Mr. President you are the best and APO...
# 1    Charlie Gaddi  'Pagpapalain nawA po kayo!...' tanong ko lang ...
# 2  Bernard Austria  Good luck Kuya Berns... :smiling_face: Godbles...
# 3     Abner Afuang  I vote for you po True :thumbs_up::thumbs_up::...
# 4     Raffy Alunan  Vote ko PO kau Vote alunan I voted for you mr ...
#
#    Comment Count  Platform                                    Translated_text  \
# 0           1929  Facebook  Salamat Mr. President you are the best and APO...
# 1              3  Facebook  'Blessed be you! ...' I only asked if you were...
# 2              8  Facebook  Good luck Kuya Berns ...: smiling_face: Godble...
# 3            404  Facebook  I vote for you po True :thumbs_up::thumbs_up::...
# 4           4607  Facebook  Vote ko PO kau Vote alunan I voted for you mr ...
#
#    word_count                                         clean_text
# 0       23829  salamat mr president best apo marcos !!!!!! go...
# 1          15  blessed ...' asked graduate manuel dela fuente...
# 2          75  good luck kuya bern ...: smiling_face godbless...
# 3        4786  vote po true thumbs_up :: thumbs_up :: thumbs_...
# 4       44964  vote ko po kau vote alunan voted mr senator re...

# %%
fb_profile = fb_df_summary.copy()

# %%
fb_profile = fb_profile[fb_profile['word_count']>=100]

# %%
#copy Personality Insights API credentials here
# url=''
# apikey = ''

personality_insights = PersonalityInsights(url=url, iam_apikey=apikey, version='2017-10-13')
# Out:
# /opt/venv/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: watson-developer-cloud moved to ibm-watson. To get updates, use the new package.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
fb_profile['pia']= fb_profile['clean_text'].apply(lambda x: personality_insights.profile(x, content_type='text/plain',raw_scores=True).get_result())

# %%
fb_profiles_df = pd.DataFrame([])

for i in fb_profile.index:
    row=fb_profile['pia'][i]
    cand = fb_profile['Candidate'][i]
    needs = pd.DataFrame([{need['name'] : need['percentile'] for need in row['needs']}], index = [cand])
    val = pd.DataFrame([{val['name'] : val['percentile'] for val in row['values']}], index = [cand])
    ocean = pd.DataFrame([{big5['name'] : big5['percentile'] for big5 in row['personality']}], index = [cand])

    traits={}

    for big5 in row['personality']:
        for child in big5['children']:
            traits[str(child['name'])] = child['percentile']

    traits = pd.DataFrame([traits], index = [cand])
    temp = needs.join([val,ocean,traits])
    fb_profiles_df=pd.concat([fb_profiles_df,temp])

# %%
fb_profiles_df
# Out:
#                    Challenge  Closeness  Curiosity  Excitement   Harmony  \
# Bong Go             0.277451   0.588992   0.954011    0.444973  0.595876
# Abner Afuang        0.294631   0.416068   0.891295    0.395108  0.374589
# Raffy Alunan        0.274095   0.586411   0.942743    0.415045  0.603707
# Pilo Hilbay         0.296092   0.475930   0.958855    0.410320  0.470092
# Samira Gutoc        0.285378   0.635685   0.972334    0.450044  0.684467
# Emily Mallillin     0.051203   0.270341   0.245855    0.033637  0.424954
# Koko Pimentel       0.213714   0.819907   0.924320    0.440270  0.860908
# Bato Dela Rosa      0.301358   0.506347   0.946465    0.419177  0.493914
# Bam Aquino          0.304710   0.654385   0.953409    0.458886  0.691576
# Bong Revilla        0.262162   0.666673   0.904813    0.455176  0.654855
# Jinggoy Estrada     0.293012   0.443610   0.897245    0.400170  0.409828
# Chel Diokno         0.285322   0.624013   0.974254    0.445306  0.673727
# Juan Ponce Enrile   0.253134   0.670299   0.932380    0.436741  0.686563
# Cynthia Villar      0.284962   0.479504   0.941026    0.404940  0.454468
# Romy Macalintal     0.357452   0.819464   0.979744    0.475785  0.920062
# Imee Marcos         0.211465   0.791285   0.953415    0.485012  0.874922
# Jiggy Manicad       0.271976   0.608011   0.972240    0.425929  0.628953
# Mar Roxas           0.296010   0.445576   0.923773    0.403698  0.426091
# Joan Nalliw         0.268348   0.816837   0.968988    0.498475  0.851263
# Ernesto Arellano    0.298141   0.435493   0.935789    0.400625  0.405759
# Willie Ong          0.188531   0.694551   0.948765    0.384277  0.705974
# Dan Roleda          0.269693   0.570782   0.936645    0.413953  0.566232
# Nancy Binay         0.254786   0.615927   0.910712    0.420298  0.590415
# Grace Poe           0.300617   0.352545   0.792421    0.386658  0.294049
# Butch Valdes        0.101838   0.237453   0.329509    0.104504  0.607114
# Lito Lapid          0.144979   0.908861   0.420096    0.440599  0.987035
# Pia Cayetano        0.247684   0.759631   0.928840    0.433792  0.734210
# Dong Mangudadatu    0.272337   0.573818   0.895526    0.413287  0.572699
# Agnes Escudero      0.027243   0.262251   0.390519    0.076504  0.482496
# RJ Javellana        0.245656   0.813855   0.795903    0.200526  0.928663
# Marcelino Arias     0.032178   0.571164   0.194701    0.137692  0.542224
# Erin Tañada         0.294695   0.609665   0.960250    0.455144  0.639278
# Serge Osmeña        0.089377   0.486827   0.517636    0.081427  0.806096
# Gary Alejano        0.283699   0.512971   0.944688    0.412988  0.522789
# Shariff Albani      0.161394   0.709319   0.516278    0.207671  0.943268
# Faisal Mangondato   0.405806   0.631224   0.417274    0.266016  0.781841
# Larry Gadon         0.280509   0.557158   0.932154    0.428415  0.553951
# Neri Colmenares     0.300034   0.367886   0.867273    0.389581  0.316084
# Sonny Angara        0.283745   0.527477   0.920066    0.416259  0.511595
# Sonny Matula        0.147393   0.838909   0.359837    0.257801  0.923141
# Ka Leody            0.048385   0.566756   0.387274    0.215402  0.931138
# Gen Pederalismo     0.300123   0.452727   0.933697    0.403235  0.434369
# Francis Tolentino   0.275232   0.535025   0.924296    0.409550  0.525135
# Glenn Chong         0.269959   0.561252   0.916973    0.410718  0.601555
# Toti Casino         0.263770   0.611671   0.932122    0.422064  0.639472
# JV Ejercito         0.296629   0.417893   0.903579    0.396879  0.375045
#
#                       Ideal   Liberty      Love  Practicality  \
# Bong Go            0.361360  0.777409  0.526197      0.687256
# Abner Afuang       0.312939  0.576307  0.438414      0.580854
# Raffy Alunan       0.351845  0.627322  0.482268      0.682361
# Pilo Hilbay        0.327170  0.672215  0.465420      0.732118
# Samira Gutoc       0.393544  0.728918  0.528295      0.735080
# Emily Mallillin    0.050053  0.052246  0.275428      0.057899
# Koko Pimentel      0.435964  0.697677  0.656010      0.327741
# Bato Dela Rosa     0.336597  0.685414  0.477358      0.734943
# Bam Aquino         0.395503  0.735388  0.547620      0.803512
# Bong Revilla       0.400731  0.786061  0.578522      0.526328
# Jinggoy Estrada    0.322020  0.589304  0.449385      0.594541
# Chel Diokno        0.373476  0.737003  0.520665      0.743545
# Juan Ponce Enrile  0.380470  0.666676  0.543994      0.653757
# Cynthia Villar     0.323764  0.624254  0.466514      0.563301
# Romy Macalintal    0.511409  0.666869  0.703273      0.760467
# Imee Marcos        0.456372  0.652040  0.612376      0.456045
# Jiggy Manicad      0.373021  0.743219  0.536631      0.679795
# Mar Roxas          0.317265  0.645410  0.456468      0.687427
# Joan Nalliw        0.493075  0.815203  0.611445      0.743972
# Ernesto Arellano   0.327583  0.593237  0.447963      0.610904
# Willie Ong         0.347310  0.606822  0.555145      0.305563
# Dan Roleda         0.343914  0.690630  0.497718      0.595831
# Nancy Binay        0.362103  0.682751  0.535287      0.342709
# Grace Poe          0.298251  0.481336  0.420012      0.487691
# Butch Valdes       0.290187  0.151616  0.297173      0.502014
# Lito Lapid         0.628261  0.508205  0.740064      0.683720
# Pia Cayetano       0.420038  0.698363  0.604883      0.348726
# Dong Mangudadatu   0.351462  0.582790  0.447118      0.705375
# Agnes Escudero     0.134623  0.168682  0.197559      0.484980
# RJ Javellana       0.632950  0.407057  0.798376      0.108528
# Marcelino Arias    0.395446  0.206449  0.432150      0.284758
# Erin Tañada        0.383655  0.717372  0.519617      0.813193
# Serge Osmeña       0.248062  0.091349  0.220940      0.422431
# Gary Alejano       0.331187  0.657703  0.476099      0.696820
# Shariff Albani     0.579192  0.240172  0.449824      0.521415
# Faisal Mangondato  0.482241  0.296051  0.342715      0.401370
# Larry Gadon        0.354834  0.694706  0.494475      0.667629
# Neri Colmenares    0.302365  0.538666  0.424241      0.606231
# Sonny Angara       0.342900  0.646150  0.482368      0.644633
# Sonny Matula       0.558443  0.417150  0.797690      0.319846
# Ka Leody           0.366395  0.223403  0.485536      0.472634
# Gen Pederalismo    0.325143  0.605461  0.455126      0.693665
# Francis Tolentino  0.343957  0.629993  0.471276      0.647767
# Glenn Chong        0.339674  0.591533  0.488983      0.606753
# Toti Casino        0.365261  0.637469  0.505561      0.602600
# JV Ejercito        0.309374  0.579310  0.437972      0.623285
#
#                    Self-expression  ...   Modesty  Uncompromising  Sympathy  \
# Bong Go                   0.958058  ...  0.553728        0.310322  0.564614
# Abner Afuang              0.862449  ...  0.563389        0.333343  0.601964
# Raffy Alunan              0.931878  ...  0.533180        0.304513  0.568428
# Pilo Hilbay               0.927585  ...  0.537539        0.315089  0.590272
# Samira Gutoc              0.980039  ...  0.521523        0.290326  0.558908
# Emily Mallillin           0.164593  ...  0.255147        0.884407  0.987398
# Koko Pimentel             0.908808  ...  0.511907        0.289142  0.531217
# Bato Dela Rosa            0.957264  ...  0.550682        0.314235  0.580920
# Bam Aquino                0.975308  ...  0.503183        0.290804  0.548273
# Bong Revilla              0.987403  ...  0.595576        0.324176  0.563203
# Jinggoy Estrada           0.881740  ...  0.564634        0.330974  0.596899
# Chel Diokno               0.961607  ...  0.502553        0.292056  0.560052
# Juan Ponce Enrile         0.954083  ...  0.528728        0.291879  0.533490
# Cynthia Villar            0.927750  ...  0.563896        0.334912  0.594780
# Romy Macalintal           0.976042  ...  0.280233        0.236094  0.472900
# Imee Marcos               0.982022  ...  0.563346        0.354916  0.504675
# Jiggy Manicad             0.980799  ...  0.546564        0.343268  0.590075
# Mar Roxas                 0.918144  ...  0.555537        0.325725  0.597504
# Joan Nalliw               0.963591  ...  0.520709        0.302899  0.516166
# Ernesto Arellano          0.875614  ...  0.555387        0.326463  0.594931
# Willie Ong                0.950701  ...  0.624444        0.424377  0.600547
# Dan Roleda                0.942717  ...  0.563764        0.324671  0.578191
# Nancy Binay               0.919091  ...  0.578812        0.318604  0.565768
# Grace Poe                 0.732532  ...  0.565728        0.343053  0.612415
# Butch Valdes              0.531895  ...  0.024691        0.390100  0.895758
# Lito Lapid                0.979185  ...  0.392860        0.405507  0.773222
# Pia Cayetano              0.983159  ...  0.622939        0.387118  0.557035
# Dong Mangudadatu          0.915181  ...  0.550558        0.319010  0.559030
# Agnes Escudero            0.281751  ...  0.031495        0.478393  0.911278
# RJ Javellana              0.900919  ...  0.132363        0.840119  0.989089
# Marcelino Arias           0.722066  ...  0.783349        0.687244  0.626810
# Erin Tañada               0.972165  ...  0.524044        0.290785  0.542939
# Serge Osmeña              0.746169  ...  0.282511        0.854717  0.976815
# Gary Alejano              0.934703  ...  0.538558        0.314489  0.584003
# Shariff Albani            0.767266  ...  0.185674        0.579268  0.877250
# Faisal Mangondato         0.642409  ...  0.270682        0.743130  0.846171
# Larry Gadon               0.960843  ...  0.548100        0.293781  0.570478
# Neri Colmenares           0.803685  ...  0.562456        0.338500  0.610004
# Sonny Angara              0.945156  ...  0.556948        0.321704  0.582235
# Sonny Matula              0.774960  ...  0.227037        0.666786  0.907621
# Ka Leody                  0.897902  ...  0.129348        0.585381  0.984420
# Gen Pederalismo           0.891486  ...  0.536119        0.323005  0.590690
# Francis Tolentino         0.914604  ...  0.560523        0.325449  0.578407
# Glenn Chong               0.957702  ...  0.547844        0.309521  0.571347
# Toti Casino               0.945644  ...  0.526373        0.299843  0.559351
# JV Ejercito               0.837704  ...  0.556854        0.328904  0.598180
#
#                       Trust     Fiery  Prone to worry  Melancholy  \
# Bong Go            0.505812  0.585779        0.739281    0.799756
# Abner Afuang       0.446972  0.602583        0.754094    0.814380
# Raffy Alunan       0.450578  0.622159        0.762070    0.803698
# Pilo Hilbay        0.387470  0.624231        0.780787    0.808733
# Samira Gutoc       0.419569  0.680196        0.832126    0.809266
# Emily Mallillin    0.347770  0.132650        0.180373    0.142592
# Koko Pimentel      0.609558  0.609567        0.748269    0.766518
# Bato Dela Rosa     0.397440  0.598897        0.738031    0.806310
# Bam Aquino         0.420920  0.621974        0.762617    0.792134
# Bong Revilla       0.545364  0.596747        0.745851    0.811243
# Jinggoy Estrada    0.442318  0.597667        0.757126    0.813215
# Chel Diokno        0.448592  0.653427        0.791701    0.798698
# Juan Ponce Enrile  0.450041  0.618718        0.768605    0.801285
# Cynthia Villar     0.383874  0.611805        0.761741    0.811400
# Romy Macalintal    0.523283  0.721505        0.811555    0.724784
# Imee Marcos        0.483642  0.612848        0.746804    0.736497
# Jiggy Manicad      0.478991  0.600504        0.719261    0.795245
# Mar Roxas          0.387022  0.602777        0.762096    0.810549
# Joan Nalliw        0.638055  0.645756        0.793363    0.790182
# Ernesto Arellano   0.444926  0.604637        0.770353    0.813875
# Willie Ong         0.619087  0.558406        0.713726    0.793665
# Dan Roleda         0.526687  0.594364        0.752002    0.805757
# Nancy Binay        0.487115  0.611779        0.780354    0.811934
# Grace Poe          0.420332  0.603468        0.745068    0.814195
# Butch Valdes       0.330698  0.625160        0.483069    0.331233
# Lito Lapid         0.533858  0.879796        0.646512    0.741849
# Pia Cayetano       0.571322  0.544471        0.680555    0.785646
# Dong Mangudadatu   0.534032  0.587937        0.737067    0.802743
# Agnes Escudero     0.185657  0.576082        0.241906    0.311576
# RJ Javellana       0.918541  0.195584        0.521685    0.240734
# Marcelino Arias    0.346696  0.397796        0.568236    0.704790
# Erin Tañada        0.390756  0.643503        0.797225    0.803680
# Serge Osmeña       0.259514  0.481452        0.354265    0.266928
# Gary Alejano       0.434789  0.614552        0.770177    0.806279
# Shariff Albani     0.701384  0.491036        0.488637    0.406366
# Faisal Mangondato  0.972106  0.224199        0.394076    0.365103
# Larry Gadon        0.420370  0.645540        0.804030    0.818633
# Neri Colmenares    0.389568  0.605706        0.754214    0.813987
# Sonny Angara       0.429945  0.613407        0.767248    0.811380
# Sonny Matula       0.911347  0.390477        0.525074    0.453852
# Ka Leody           0.490761  0.771973        0.698766    0.643367
# Gen Pederalismo    0.480823  0.591509        0.751287    0.806771
# Francis Tolentino  0.469027  0.589097        0.739164    0.806081
# Glenn Chong        0.455838  0.617104        0.757061    0.800893
# Toti Casino        0.452224  0.613493        0.761811    0.794725
# JV Ejercito        0.411718  0.605280        0.755982    0.813141
#
#                    Immoderation  Self-consciousness  Susceptible to stress
# Bong Go                0.057815            0.818450               0.768938
# Abner Afuang           0.237014            0.784075               0.767739
# Raffy Alunan           0.039118            0.848068               0.783182
# Pilo Hilbay            0.124088            0.817082               0.780377
# Samira Gutoc           0.026986            0.882307               0.835397
# Emily Mallillin        0.000488            0.066480               0.073596
# Koko Pimentel          0.005182            0.823522               0.781976
# Bato Dela Rosa         0.132318            0.823439               0.779657
# Bam Aquino             0.024002            0.848455               0.767452
# Bong Revilla           0.067086            0.817881               0.790598
# Jinggoy Estrada        0.193174            0.798722               0.776426
# Chel Diokno            0.034292            0.861110               0.811727
# Juan Ponce Enrile      0.022133            0.862714               0.800426
# Cynthia Villar         0.141766            0.809465               0.788075
# Romy Macalintal        0.001205            0.883820               0.771438
# Imee Marcos            0.006000            0.870512               0.774213
# Jiggy Manicad          0.056472            0.785862               0.737960
# Mar Roxas              0.171529            0.793715               0.770633
# Joan Nalliw            0.004372            0.895678               0.825204
# Ernesto Arellano       0.182459            0.807303               0.775784
# Willie Ong             0.038941            0.818219               0.756448
# Dan Roleda             0.050573            0.817862               0.786353
# Nancy Binay            0.055804            0.832140               0.826194
# Grace Poe              0.502946            0.741046               0.740622
# Butch Valdes           0.002392            0.342482               0.184796
# Lito Lapid             0.007186            0.715634               0.600830
# Pia Cayetano           0.022142            0.819585               0.778892
# Dong Mangudadatu       0.039566            0.841009               0.774950
# Agnes Escudero         0.008420            0.333527               0.134904
# RJ Javellana           0.001059            0.077670               0.274419
# Marcelino Arias        0.002621            0.610221               0.670714
# Erin Tañada            0.036687            0.882003               0.814575
# Serge Osmeña           0.000082            0.331487               0.230008
# Gary Alejano           0.081753            0.821161               0.773933
# Shariff Albani         0.000155            0.369092               0.372654
# Faisal Mangondato      0.000408            0.280521               0.343868
# Larry Gadon            0.088561            0.852451               0.818715
# Neri Colmenares        0.403214            0.756950               0.752184
# Sonny Angara           0.101078            0.826548               0.791571
# Sonny Matula           0.005696            0.166114               0.337876
# Ka Leody               0.008605            0.502852               0.486340
# Gen Pederalismo        0.142661            0.803015               0.758148
# Francis Tolentino      0.066417            0.823876               0.760402
# Glenn Chong            0.041812            0.838152               0.757477
# Toti Casino            0.028939            0.840966               0.782597
# JV Ejercito            0.232200            0.791872               0.771687
#
# [46 rows x 52 columns]

# %%
fb_pia_scores = fb_profiles_df.reset_index()
fb_pia_data = fb_profile.merge(fb_pia_scores, left_on='Candidate', right_on='index').drop(columns='index')
fb_pia_data.to_csv('FB_Audience_PersonalityScores_Percentiles.csv')

# %%
fb_profiles_raw=pd.DataFrame([])

for i in fb_profile.index:
    row=fb_profile['pia'][i]
    cand = fb_profile['Candidate'][i]
    needs = pd.DataFrame([{need['name'] : need['raw_score'] for need in row['needs']}], index = [cand])
    val = pd.DataFrame([{val['name'] : val['raw_score'] for val in row['values']}], index = [cand])
    ocean = pd.DataFrame([{big5['name'] : big5['raw_score'] for big5 in row['personality']}], index = [cand])

    traits={}

    for big5 in row['personality']:
        for child in big5['children']:
            traits[str(child['name'])] = child['raw_score']

    traits = pd.DataFrame([traits], index = [cand])
    temp = needs.join([val,ocean,traits])
    fb_profiles_raw=pd.concat([fb_profiles_raw,temp])

# %%
fb_pia_rawscores = fb_profiles_raw.reset_index()
fb_pia_rawdata = fb_profile.merge(fb_pia_rawscores, left_on='Candidate', right_on='index').drop(columns='index')
fb_pia_rawdata.to_csv('FB_Audience_PersonalityScores_Raw.csv')

# %% [markdown]
# ## Profiling Twitter mentions

# %%
twit_df = pd.read_csv('twitter_cleaned.csv')

# %%
twit_df.shape
# Out:
# (259029, 8)

# %%
twit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 259029 entries, 0 to 259028
# Data columns (total 8 columns):
# candidate_num    259029 non-null int64
# text             259029 non-null object
# date             259029 non-null object
# favorites        259029 non-null int64
# retweets         259029 non-null int64
# replies          259029 non-null int64
# hashtags         53444 non-null object
# mentions         50610 non-null object
# dtypes: int64(4), object(4)
# memory usage: 15.8+ MB

# %%
twit_df.head()
# Out:
#    candidate_num                                               text  \
# 0              1  Here is the certified list of senatorial candi...
# 1              1                            Who is Vangie Abejo 😭😭😭
# 2              1  VANGIE ABEJO Independent Vangie Abejo served a...
# 3              1                                     Abejo, Vangie
# 4              1  Inclined not to vote for: ARIAS, MARCELINO CAC...
#
#                         date  favorites  retweets  replies hashtags mentions
# 0  2019-02-12 12:45:05+08:00          0         0        0      NaN      NaN
# 1  2019-03-06 17:35:05+08:00          0         0        0      NaN      NaN
# 2  2019-03-16 23:11:42+08:00          2         0        1      NaN      NaN
# 3  2019-03-27 18:54:08+08:00          0         0        0      NaN      NaN
# 4  2019-03-30 23:54:06+08:00          0         0        1      NaN      NaN

# %%
twit_df.isnull().sum()
# Out:
# candidate_num         0
# text                  0
# date                  0
# favorites             0
# retweets              0
# replies               0
# hashtags         205585
# mentions         208419
# dtype: int64

# %%
twit_df = twit_df[['candidate_num', 'text']]

# %%
display(twit_df[twit_df['text']=='None'])
display(twit_df[twit_df['text']==''])
display(twit_df[twit_df['text']=='[]'])
# Out:
# Empty DataFrame
# Columns: [candidate_num, text]
# Index: []
# Empty DataFrame
# Columns: [candidate_num, text]
# Index: []
# Empty DataFrame
# Columns: [candidate_num, text]
# Index: []

# %%
twit_df['text'] = twit_df['text'].apply(emoji.demojize)

# %%
cndnlist=[]
twtlist=[]
twtcount=[]

for i in twit_df['candidate_num'].unique():
    cndnlist.append(i)
    twtlist.append(' '.join((twit_df[twit_df['candidate_num']==i]['text']).to_list()))
    twtcount.append(len(twit_df[twit_df['candidate_num']==i]))

twit_df_summary=pd.DataFrame({'Candidate_num': cndnlist, 'Text': twtlist, 'Post Count': twtcount})
twit_df_summary['Platform']='Twitter'

# %%
twit_df_summary.shape
# Out:
# (62, 4)

# %%
twit_df_summary['Text'] = twit_df_summary['Text'].apply(str).apply(lambda x: x.replace('[','').replace(']','').strip())
# twit_df_summary['Translated_text'] = twit_df_summary['Text'].apply(str).apply(translator.translate).apply(lambda x: x.text)

# %%
trans=[]

for i in range(len(twit_df_summary)):
    try:
        trans.append(translator.translate(twit_df_summary['Text'][i]).text)
        print(str(i) + " ok")
    except:
        trans.append(twit_df_summary['Text'][i])
        print(str(i) + " can't translate")
# Out:
# 0 ok
# 1 ok
# 2 ok
# 3 ok
# 4 can't translate
# 5 ok
# 6 ok
# 7 can't translate
# 8 can't translate
# 9 ok
# 10 ok
# 11 ok
# 12 ok
# 13 ok
# 14 ok
# 15 can't translate
# 16 ok
# 17 ok
# 18 ok
# 19 ok
# 20 ok
# 21 can't translate
# 22 ok
# 23 can't translate
# 24 can't translate
# 25 can't translate
# 26 ok
# 27 ok
# 28 ok
# 29 ok
# 30 ok
# 31 can't translate
# 32 ok
# 33 can't translate
# 34 ok
# 35 can't translate
# 36 ok
# 37 ok
# 38 ok
# 39 can't translate
# 40 ok
# 41 ok
# 42 ok
# 43 ok
# 44 can't translate
# 45 can't translate
# 46 ok
# 47 ok
# 48 ok
# 49 ok
# 50 ok
# 51 ok
# 52 ok
# 53 can't translate
# 54 can't translate
# 55 ok
# 56 can't translate
# 57 ok
# 58 can't translate
# 59 can't translate
# 60 ok
# 61 can't translate

# %%
twit_df_summary['Translated_text']=trans

# %%
twit_df_summary['word_count'] = twit_df_summary['Translated_text'].apply(text_cleaner).apply(lambda x: x[0])
twit_df_summary['clean_text'] = twit_df_summary['Translated_text'].apply(text_cleaner).apply(lambda x: x[1])

twit_profile = twit_df_summary.copy()
twit_profile = twit_profile[twit_profile['word_count']>=100]

# %%
twit_profile['pia']= twit_profile['clean_text'].apply(lambda x: personality_insights.profile(x, content_type='text/plain',raw_scores=True).get_result())

# %%
twit_profiles_df = pd.DataFrame([])

for i in twit_profile.index:
    row=twit_profile['pia'][i]
    cand = twit_profile['Candidate_num'][i]
    needs = pd.DataFrame([{need['name'] : need['percentile'] for need in row['needs']}], index = [cand])
    val = pd.DataFrame([{val['name'] : val['percentile'] for val in row['values']}], index = [cand])
    ocean = pd.DataFrame([{big5['name'] : big5['percentile'] for big5 in row['personality']}], index = [cand])

    traits={}

    for big5 in row['personality']:
        for child in big5['children']:
            traits[str(child['name'])] = child['percentile']

    traits = pd.DataFrame([traits], index = [cand])
    temp = needs.join([val,ocean,traits])
    twit_profiles_df=pd.concat([twit_profiles_df,temp])

twit_pia_scores = twit_profiles_df.reset_index()
twit_pia_data = twit_profile.merge(twit_pia_scores, left_on='Candidate_num', right_on='index').drop(columns='index')
twit_pia_data.to_csv('Twitter_Audience_PersonalityScores_Percentiles.csv')

# %%
twit_profiles_raw=pd.DataFrame([])

for i in twit_profile.index:
    row = twit_profile['pia'][i]
    cand = twit_profile['Candidate_num'][i]
    needs = pd.DataFrame([{need['name'] : need['raw_score'] for need in row['needs']}], index = [cand])
    val = pd.DataFrame([{val['name'] : val['raw_score'] for val in row['values']}], index = [cand])
    ocean = pd.DataFrame([{big5['name'] : big5['raw_score'] for big5 in row['personality']}], index = [cand])

    traits={}

    for big5 in row['personality']:
        for child in big5['children']:
            traits[str(child['name'])] = child['raw_score']

    traits = pd.DataFrame([traits], index = [cand])
    temp = needs.join([val,ocean,traits])
    twit_profiles_raw=pd.concat([twit_profiles_raw,temp])

twit_pia_rawscores = twit_profiles_raw.reset_index()
twit_pia_rawdata = twit_profile.merge(twit_pia_rawscores, left_on='Candidate_num', right_on='index').drop(columns='index')
twit_pia_rawdata.to_csv('Twitter_Audience_PersonalityScores_Raw.csv')

# %% [markdown]
# ## Combining audience scores from Facebook and Twitter

# %% [markdown]
# If using percentiles, opt for scores from Twitter audience. Has data for audience of all personalities

# %%
candidates=pd.read_csv('agg_candidate.csv')[['#', 'candidate']]

# %%
candidates.head()
# Out:
#    #        candidate
# 0  1     Vangie Abejo
# 1  2     Abner Afuang
# 2  3  Freddie Aguilar
# 3  4   Shariff Albani
# 4  5     Gary Alejano

# %%
twit_aud = twit_pia_data.merge(candidates, left_on='Candidate_num', right_on='#')

# %%
twit_aud.head()
# Out:
#    Candidate_num                                               Text  \
# 0              1  Here is the certified list of senatorial candi...
# 1              2  Here is the certified list of senatorial candi...
# 2              3  may kulang, sina Freddie Aguilar at Lito Lapid...
# 3              4  Here is the certified list of senatorial candi...
# 4              5  If you think that’s bad, you should see Ilocos...
#
#    Post Count Platform                                    Translated_text  \
# 0          13  Twitter  Here is the certified list of senatorial candi...
# 1         199  Twitter  Here is the certified list of senatorial candi...
# 2        1701  Twitter  may kulang, sina Freddie Aguilar at Lito Lapid...
# 3         119  Twitter  Here is the certified list of senatorial candi...
# 4       10837  Twitter  If you think that’s bad, you should see Ilocos...
#
#    word_count                                         clean_text  \
# 0         332  certified list senatorial candidate may 2019 p...
# 1        3290  certified list senatorial candidate may 2019 p...
# 2       28520  may kulang sina freddie aguilar lito lapid hug...
# 3        2929  certified list senatorial candidate may 2019 p...
# 4      184785  think ’ bad see ilocos dito sa sipalay pinatan...
#
#                                                  pia  Challenge  Closeness  \
# 0  {'word_count': 298, 'word_count_message': 'The...   0.040886   0.502701
# 1  {'word_count': 3268, 'processed_language': 'en...   0.225200   0.753283
# 2  {'word_count': 28661, 'processed_language': 'e...   0.182894   0.673239
# 3  {'word_count': 2759, 'processed_language': 'en...   0.275165   0.740147
# 4  {'word_count': 38406, 'processed_language': 'e...   0.287582   0.632948
#
#    ...  Sympathy     Trust     Fiery  Prone to worry  Melancholy  \
# 0  ...  0.811167  0.209482  0.977056        0.991719    0.949507
# 1  ...  0.461449  0.238956  0.873692        0.946612    0.834778
# 2  ...  0.524033  0.216106  0.787384        0.877754    0.846714
# 3  ...  0.489494  0.426106  0.711497        0.906900    0.800035
# 4  ...  0.545506  0.356750  0.672221        0.826341    0.801160
#
#    Immoderation  Self-consciousness  Susceptible to stress  #        candidate
# 0      0.019149            0.978811               0.945928  1     Vangie Abejo
# 1      0.001465            0.974206               0.846837  2     Abner Afuang
# 2      0.041326            0.934077               0.860202  3  Freddie Aguilar
# 3      0.001778            0.958155               0.822721  4   Shariff Albani
# 4      0.023004            0.883764               0.805235  5     Gary Alejano
#
# [5 rows x 62 columns]

# %%
twit_aud.columns
# Out:
# Index(['Candidate_num', 'Text', 'Post Count', 'Platform', 'Translated_text',
#        'word_count', 'clean_text', 'pia', 'Challenge', 'Closeness',
#        'Curiosity', 'Excitement', 'Harmony', 'Ideal', 'Liberty', 'Love',
#        'Practicality', 'Self-expression', 'Stability', 'Structure',
#        'Conservation', 'Openness to change', 'Hedonism', 'Self-enhancement',
#        'Self-transcendence', 'Openness', 'Conscientiousness', 'Extraversion',
#        'Agreeableness', 'Emotional range', 'Adventurousness',
#        'Artistic interests', 'Emotionality', 'Imagination', 'Intellect',
#        'Authority-challenging', 'Achievement striving', 'Cautiousness',
#        'Dutifulness', 'Orderliness', 'Self-discipline', 'Self-efficacy',
#        'Activity level', 'Assertiveness', 'Cheerfulness', 'Excitement-seeking',
#        'Outgoing', 'Gregariousness', 'Altruism', 'Cooperation', 'Modesty',
#        'Uncompromising', 'Sympathy', 'Trust', 'Fiery', 'Prone to worry',
#        'Melancholy', 'Immoderation', 'Self-consciousness',
#        'Susceptible to stress', '#', 'candidate'],
#       dtype='object')

# %%
twit_aud = twit_aud[['candidate','Post Count', 'Platform', 'Challenge', 'Closeness',
       'Curiosity', 'Excitement', 'Harmony', 'Ideal', 'Liberty', 'Love',
       'Practicality', 'Self-expression', 'Stability', 'Structure',
       'Conservation', 'Openness to change', 'Hedonism', 'Self-enhancement',
       'Self-transcendence', 'Openness', 'Conscientiousness', 'Extraversion',
       'Agreeableness', 'Emotional range', 'Adventurousness',
       'Artistic interests', 'Emotionality', 'Imagination', 'Intellect',
       'Authority-challenging', 'Achievement striving', 'Cautiousness',
       'Dutifulness', 'Orderliness', 'Self-discipline', 'Self-efficacy',
       'Activity level', 'Assertiveness', 'Cheerfulness', 'Excitement-seeking',
       'Outgoing', 'Gregariousness', 'Altruism', 'Cooperation', 'Modesty',
       'Uncompromising', 'Sympathy', 'Trust', 'Fiery', 'Prone to worry',
       'Melancholy', 'Immoderation', 'Self-consciousness',
       'Susceptible to stress']].rename(columns={'candidate':'Candidate','Post Count':'Count'})

# %%
fb_aud = fb_pia_data[['Candidate', 'Comment Count', 'Platform', 'Challenge', 'Closeness',
       'Curiosity', 'Excitement', 'Harmony', 'Ideal', 'Liberty', 'Love',
       'Practicality', 'Self-expression', 'Stability', 'Structure',
       'Conservation', 'Openness to change', 'Hedonism', 'Self-enhancement',
       'Self-transcendence', 'Openness', 'Conscientiousness', 'Extraversion',
       'Agreeableness', 'Emotional range', 'Adventurousness',
       'Artistic interests', 'Emotionality', 'Imagination', 'Intellect',
       'Authority-challenging', 'Achievement striving', 'Cautiousness',
       'Dutifulness', 'Orderliness', 'Self-discipline', 'Self-efficacy',
       'Activity level', 'Assertiveness', 'Cheerfulness', 'Excitement-seeking',
       'Outgoing', 'Gregariousness', 'Altruism', 'Cooperation', 'Modesty',
       'Uncompromising', 'Sympathy', 'Trust', 'Fiery', 'Prone to worry',
       'Melancholy', 'Immoderation', 'Self-consciousness',
       'Susceptible to stress']].rename(columns={'Comment Count':'Count'})

# %%
aud = twit_aud.merge(fb_aud, how='left', on='Candidate')
aud.head()
# Out:
#          Candidate  Count_x Platform_x  Challenge_x  Closeness_x  Curiosity_x  \
# 0     Vangie Abejo       13    Twitter     0.040886     0.502701     0.444015
# 1     Abner Afuang      199    Twitter     0.225200     0.753283     0.907730
# 2  Freddie Aguilar     1701    Twitter     0.182894     0.673239     0.850364
# 3   Shariff Albani      119    Twitter     0.275165     0.740147     0.956393
# 4     Gary Alejano    10837    Twitter     0.287582     0.632948     0.966161
#
#    Excitement_x  Harmony_x   Ideal_x  Liberty_x  ...  Modesty_y  \
# 0      0.284566   0.796434  0.477860   0.183793  ...        NaN
# 1      0.403599   0.920531  0.492910   0.472906  ...   0.563389
# 2      0.420639   0.734997  0.376927   0.584469  ...        NaN
# 3      0.438261   0.853061  0.518954   0.531703  ...   0.185674
# 4      0.440037   0.694518  0.365450   0.680693  ...   0.538558
#
#    Uncompromising_y  Sympathy_y   Trust_y   Fiery_y  Prone to worry_y  \
# 0               NaN         NaN       NaN       NaN               NaN
# 1          0.333343    0.601964  0.446972  0.602583          0.754094
# 2               NaN         NaN       NaN       NaN               NaN
# 3          0.579268    0.877250  0.701384  0.491036          0.488637
# 4          0.314489    0.584003  0.434789  0.614552          0.770177
#
#    Melancholy_y  Immoderation_y  Self-consciousness_y  Susceptible to stress_y
# 0           NaN             NaN                   NaN                      NaN
# 1      0.814380        0.237014              0.784075                 0.767739
# 2           NaN             NaN                   NaN                      NaN
# 3      0.406366        0.000155              0.369092                 0.372654
# 4      0.806279        0.081753              0.821161                 0.773933
#
# [5 rows x 109 columns]

# %%
aud.shape
# Out:
# (62, 109)

# %%
scores = ['Challenge', 'Closeness',
       'Curiosity', 'Excitement', 'Harmony', 'Ideal', 'Liberty', 'Love',
       'Practicality', 'Self-expression', 'Stability', 'Structure',
       'Conservation', 'Openness to change', 'Hedonism', 'Self-enhancement',
       'Self-transcendence', 'Openness', 'Conscientiousness', 'Extraversion',
       'Agreeableness', 'Emotional range', 'Adventurousness',
       'Artistic interests', 'Emotionality', 'Imagination', 'Intellect',
       'Authority-challenging', 'Achievement striving', 'Cautiousness',
       'Dutifulness', 'Orderliness', 'Self-discipline', 'Self-efficacy',
       'Activity level', 'Assertiveness', 'Cheerfulness', 'Excitement-seeking',
       'Outgoing', 'Gregariousness', 'Altruism', 'Cooperation', 'Modesty',
       'Uncompromising', 'Sympathy', 'Trust', 'Fiery', 'Prone to worry',
       'Melancholy', 'Immoderation', 'Self-consciousness',
       'Susceptible to stress']

# %%
aud = aud.fillna(0).replace(np.nan, 0)
for col in scores:
    aud[col] = ((aud[col+'_x']*aud['Count_x']) + (aud[col+'_y']*aud['Count_y']))/(aud['Count_x']+aud['Count_y'])

# %%
scores.extend(['Candidate', 'Count_x', 'Count_y'])
aud_data = aud[scores]

# %%
aud_data.columns
# Out:
# Index(['Challenge', 'Closeness', 'Curiosity', 'Excitement', 'Harmony', 'Ideal',
#        'Liberty', 'Love', 'Practicality', 'Self-expression', 'Stability',
#        'Structure', 'Conservation', 'Openness to change', 'Hedonism',
#        'Self-enhancement', 'Self-transcendence', 'Openness',
#        'Conscientiousness', 'Extraversion', 'Agreeableness', 'Emotional range',
#        'Adventurousness', 'Artistic interests', 'Emotionality', 'Imagination',
#        'Intellect', 'Authority-challenging', 'Achievement striving',
#        'Cautiousness', 'Dutifulness', 'Orderliness', 'Self-discipline',
#        'Self-efficacy', 'Activity level', 'Assertiveness', 'Cheerfulness',
#        'Excitement-seeking', 'Outgoing', 'Gregariousness', 'Altruism',
#        'Cooperation', 'Modesty', 'Uncompromising', 'Sympathy', 'Trust',
#        'Fiery', 'Prone to worry', 'Melancholy', 'Immoderation',
#        'Self-consciousness', 'Susceptible to stress', 'Candidate', 'Count_x',
#        'Count_y'],
#       dtype='object')

# %%
aud_data=aud_data[['Candidate', 'Count_x','Count_y', 'Challenge', 'Closeness', 
        'Curiosity', 'Excitement', 'Harmony', 'Ideal',
       'Liberty', 'Love', 'Practicality', 'Self-expression', 'Stability',
       'Structure', 'Conservation', 'Openness to change', 'Hedonism',
       'Self-enhancement', 'Self-transcendence', 'Openness',
       'Conscientiousness', 'Extraversion', 'Agreeableness', 'Emotional range',
       'Adventurousness', 'Artistic interests', 'Emotionality', 'Imagination',
       'Intellect', 'Authority-challenging', 'Achievement striving',
       'Cautiousness', 'Dutifulness', 'Orderliness', 'Self-discipline',
       'Self-efficacy', 'Activity level', 'Assertiveness', 'Cheerfulness',
       'Excitement-seeking', 'Outgoing', 'Gregariousness', 'Altruism',
       'Cooperation', 'Modesty', 'Uncompromising', 'Sympathy', 'Trust',
       'Fiery', 'Prone to worry', 'Melancholy', 'Immoderation',
       'Self-consciousness', 'Susceptible to stress']].rename(columns={'Count_x': 'Twitter_count', 'Count_y': 'Facebook_count'})

# %%
aud_data.to_csv('AudienceScores_Percentiles.csv')

# %% [markdown]
# If using raw scores, weigh average of FB and Twitter raw scores. Twitter has data for audience of all personalities, FB misses some personalities

# %%
twit_aud_raw = twit_pia_rawdata.merge(candidates, left_on='Candidate_num', right_on='#')

# %%
twit_aud_raw = twit_aud_raw[['candidate','Post Count', 'Platform', 'Challenge', 'Closeness',
       'Curiosity', 'Excitement', 'Harmony', 'Ideal', 'Liberty', 'Love',
       'Practicality', 'Self-expression', 'Stability', 'Structure',
       'Conservation', 'Openness to change', 'Hedonism', 'Self-enhancement',
       'Self-transcendence', 'Openness', 'Conscientiousness', 'Extraversion',
       'Agreeableness', 'Emotional range', 'Adventurousness',
       'Artistic interests', 'Emotionality', 'Imagination', 'Intellect',
       'Authority-challenging', 'Achievement striving', 'Cautiousness',
       'Dutifulness', 'Orderliness', 'Self-discipline', 'Self-efficacy',
       'Activity level', 'Assertiveness', 'Cheerfulness', 'Excitement-seeking',
       'Outgoing', 'Gregariousness', 'Altruism', 'Cooperation', 'Modesty',
       'Uncompromising', 'Sympathy', 'Trust', 'Fiery', 'Prone to worry',
       'Melancholy', 'Immoderation', 'Self-consciousness',
       'Susceptible to stress']].rename(columns={'candidate':'Candidate','Post Count':'Count'})

# %%
fb_pia_rawdata.columns
# Out:
# Index(['Candidate', 'Comment', 'Comment Count', 'Platform', 'Translated_text',
#        'word_count', 'clean_text', 'pia', 'Challenge', 'Closeness',
#        'Curiosity', 'Excitement', 'Harmony', 'Ideal', 'Liberty', 'Love',
#        'Practicality', 'Self-expression', 'Stability', 'Structure',
#        'Conservation', 'Openness to change', 'Hedonism', 'Self-enhancement',
#        'Self-transcendence', 'Openness', 'Conscientiousness', 'Extraversion',
#        'Agreeableness', 'Emotional range', 'Adventurousness',
#        'Artistic interests', 'Emotionality', 'Imagination', 'Intellect',
#        'Authority-challenging', 'Achievement striving', 'Cautiousness',
#        'Dutifulness', 'Orderliness', 'Self-discipline', 'Self-efficacy',
#        'Activity level', 'Assertiveness', 'Cheerfulness', 'Excitement-seeking',
#        'Outgoing', 'Gregariousness', 'Altruism', 'Cooperation', 'Modesty',
#        'Uncompromising', 'Sympathy', 'Trust', 'Fiery', 'Prone to worry',
#        'Melancholy', 'Immoderation', 'Self-consciousness',
#        'Susceptible to stress'],
#       dtype='object')

# %%
fb_aud_raw = fb_pia_rawdata[['Candidate', 'Comment Count', 'Platform', 'Challenge', 'Closeness',
       'Curiosity', 'Excitement', 'Harmony', 'Ideal', 'Liberty', 'Love',
       'Practicality', 'Self-expression', 'Stability', 'Structure',
       'Conservation', 'Openness to change', 'Hedonism', 'Self-enhancement',
       'Self-transcendence', 'Openness', 'Conscientiousness', 'Extraversion',
       'Agreeableness', 'Emotional range', 'Adventurousness',
       'Artistic interests', 'Emotionality', 'Imagination', 'Intellect',
       'Authority-challenging', 'Achievement striving', 'Cautiousness',
       'Dutifulness', 'Orderliness', 'Self-discipline', 'Self-efficacy',
       'Activity level', 'Assertiveness', 'Cheerfulness', 'Excitement-seeking',
       'Outgoing', 'Gregariousness', 'Altruism', 'Cooperation', 'Modesty',
       'Uncompromising', 'Sympathy', 'Trust', 'Fiery', 'Prone to worry',
       'Melancholy', 'Immoderation', 'Self-consciousness',
       'Susceptible to stress']].rename(columns={'Comment Count':'Count'})

# %%
fb_aud_raw.columns==twit_aud_raw.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %%
scores = ['Challenge', 'Closeness',
       'Curiosity', 'Excitement', 'Harmony', 'Ideal', 'Liberty', 'Love',
       'Practicality', 'Self-expression', 'Stability', 'Structure',
       'Conservation', 'Openness to change', 'Hedonism', 'Self-enhancement',
       'Self-transcendence', 'Openness', 'Conscientiousness', 'Extraversion',
       'Agreeableness', 'Emotional range', 'Adventurousness',
       'Artistic interests', 'Emotionality', 'Imagination', 'Intellect',
       'Authority-challenging', 'Achievement striving', 'Cautiousness',
       'Dutifulness', 'Orderliness', 'Self-discipline', 'Self-efficacy',
       'Activity level', 'Assertiveness', 'Cheerfulness', 'Excitement-seeking',
       'Outgoing', 'Gregariousness', 'Altruism', 'Cooperation', 'Modesty',
       'Uncompromising', 'Sympathy', 'Trust', 'Fiery', 'Prone to worry',
       'Melancholy', 'Immoderation', 'Self-consciousness',
       'Susceptible to stress']

# %%
aud_raw = twit_aud_raw.merge(fb_aud_raw, how='left', on='Candidate')
aud_raw.head()
# Out:
#          Candidate  Count_x Platform_x  Challenge_x  Closeness_x  Curiosity_x  \
# 0     Vangie Abejo       13    Twitter     0.653725     0.793661     0.812945
# 1     Abner Afuang      199    Twitter     0.697935     0.823759     0.851573
# 2  Freddie Aguilar     1701    Twitter     0.691224     0.813285     0.843969
# 3   Shariff Albani      119    Twitter     0.704998     0.821937     0.861663
# 4     Gary Alejano    10837    Twitter     0.706648     0.808438     0.864739
#
#    Excitement_x  Harmony_x   Ideal_x  Liberty_x  ...  Modesty_y  \
# 0      0.639980   0.837881  0.688416   0.702758  ...        NaN
# 1      0.665819   0.857899  0.690210   0.733965  ...   0.456795
# 2      0.669297   0.830942  0.676153   0.744504  ...        NaN
# 3      0.672862   0.845502  0.693313   0.739492  ...   0.401205
# 4      0.673220   0.826823  0.674710   0.754105  ...   0.453484
#
#    Uncompromising_y  Sympathy_y   Trust_y   Fiery_y  Prone to worry_y  \
# 0               NaN         NaN       NaN       NaN               NaN
# 1          0.605489    0.673346  0.580310  0.549936          0.640993
# 2               NaN         NaN       NaN       NaN               NaN
# 3          0.635249    0.707824  0.607570  0.534487          0.592169
# 4          0.603013    0.671579  0.579037  0.551640          0.644539
#
#    Melancholy_y  Immoderation_y  Self-consciousness_y  Susceptible to stress_y
# 0           NaN             NaN                   NaN                      NaN
# 1      0.505073        0.473075              0.588075                 0.514222
# 2           NaN             NaN                   NaN                      NaN
# 3      0.433434        0.361965              0.529126                 0.446926
# 4      0.503180        0.447038              0.595114                 0.515524
#
# [5 rows x 109 columns]

# %%
aud_raw.columns
# Out:
# Index(['Candidate', 'Count_x', 'Platform_x', 'Challenge_x', 'Closeness_x',
#        'Curiosity_x', 'Excitement_x', 'Harmony_x', 'Ideal_x', 'Liberty_x',
#        ...
#        'Modesty_y', 'Uncompromising_y', 'Sympathy_y', 'Trust_y', 'Fiery_y',
#        'Prone to worry_y', 'Melancholy_y', 'Immoderation_y',
#        'Self-consciousness_y', 'Susceptible to stress_y'],
#       dtype='object', length=109)

# %%
aud_raw = aud_raw.fillna(0).replace(np.nan, 0)

# %%
aud_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62 entries, 0 to 61
# Columns: 161 entries, Candidate to Susceptible to stress
# dtypes: float64(157), int64(1), object(3)
# memory usage: 78.5+ KB

# %%
for col in scores:
    aud_raw[col] = ((aud_raw[col+'_x']*aud_raw['Count_x']) + (aud_raw[col+'_y']*aud_raw['Count_y']))/(aud_raw['Count_x']+aud_raw['Count_y'])

# %%
aud_raw.shape
# Out:
# (62, 161)

# %%
scores.extend(['Candidate', 'Count_x', 'Count_y'])
scores
# Out:
# ['Challenge',
#  'Closeness',
#  'Curiosity',
#  'Excitement',
#  'Harmony',
#  'Ideal',
#  'Liberty',
#  'Love',
#  'Practicality',
#  'Self-expression',
#  'Stability',
#  'Structure',
#  'Conservation',
#  'Openness to change',
#  'Hedonism',
#  'Self-enhancement',
#  'Self-transcendence',
#  'Openness',
#  'Conscientiousness',
#  'Extraversion',
#  'Agreeableness',
#  'Emotional range',
#  'Adventurousness',
#  'Artistic interests',
#  'Emotionality',
#  'Imagination',
#  'Intellect',
#  'Authority-challenging',
#  'Achievement striving',
#  'Cautiousness',
#  'Dutifulness',
#  'Orderliness',
#  'Self-discipline',
#  'Self-efficacy',
#  'Activity level',
#  'Assertiveness',
#  'Cheerfulness',
#  'Excitement-seeking',
#  'Outgoing',
#  'Gregariousness',
#  'Altruism',
#  'Cooperation',
#  'Modesty',
#  'Uncompromising',
#  'Sympathy',
#  'Trust',
#  'Fiery',
#  'Prone to worry',
#  'Melancholy',
#  'Immoderation',
#  'Self-consciousness',
#  'Susceptible to stress',
#  'Candidate',
#  'Count_x',
#  'Count_y']

# %%
aud_raw_data = aud_raw[scores]

# %%
aud_raw_data.columns
# Out:
# Index(['Challenge', 'Closeness', 'Curiosity', 'Excitement', 'Harmony', 'Ideal',
#        'Liberty', 'Love', 'Practicality', 'Self-expression', 'Stability',
#        'Structure', 'Conservation', 'Openness to change', 'Hedonism',
#        'Self-enhancement', 'Self-transcendence', 'Openness',
#        'Conscientiousness', 'Extraversion', 'Agreeableness', 'Emotional range',
#        'Adventurousness', 'Artistic interests', 'Emotionality', 'Imagination',
#        'Intellect', 'Authority-challenging', 'Achievement striving',
#        'Cautiousness', 'Dutifulness', 'Orderliness', 'Self-discipline',
#        'Self-efficacy', 'Activity level', 'Assertiveness', 'Cheerfulness',
#        'Excitement-seeking', 'Outgoing', 'Gregariousness', 'Altruism',
#        'Cooperation', 'Modesty', 'Uncompromising', 'Sympathy', 'Trust',
#        'Fiery', 'Prone to worry', 'Melancholy', 'Immoderation',
#        'Self-consciousness', 'Susceptible to stress', 'Candidate', 'Count_x',
#        'Count_y'],
#       dtype='object')

# %%
aud_raw_data = aud_raw_data[['Candidate', 'Count_x','Count_y', 'Challenge', 'Closeness', 
        'Curiosity', 'Excitement', 'Harmony', 'Ideal',
       'Liberty', 'Love', 'Practicality', 'Self-expression', 'Stability',
       'Structure', 'Conservation', 'Openness to change', 'Hedonism',
       'Self-enhancement', 'Self-transcendence', 'Openness',
       'Conscientiousness', 'Extraversion', 'Agreeableness', 'Emotional range',
       'Adventurousness', 'Artistic interests', 'Emotionality', 'Imagination',
       'Intellect', 'Authority-challenging', 'Achievement striving',
       'Cautiousness', 'Dutifulness', 'Orderliness', 'Self-discipline',
       'Self-efficacy', 'Activity level', 'Assertiveness', 'Cheerfulness',
       'Excitement-seeking', 'Outgoing', 'Gregariousness', 'Altruism',
       'Cooperation', 'Modesty', 'Uncompromising', 'Sympathy', 'Trust',
       'Fiery', 'Prone to worry', 'Melancholy', 'Immoderation',
       'Self-consciousness', 'Susceptible to stress']].rename(columns={'Count_x': 'Twitter_count', 'Count_y': 'Facebook_count'})

# %%
aud_raw_data.to_csv('AudienceScores_Raw.csv')
